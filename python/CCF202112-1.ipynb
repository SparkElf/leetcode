# %%
n, N = list(map(int, input().split(" ")))
a=list(map(int,input().split(" ")))
a.insert(0,0)
ans=0
for i in range(len(a)-1):
    ans+=(a[i+1]-a[i])*i
ans+=(N-a[-1])*(len(a)-1)
print(ans)
# Out:
# 9
# 15
